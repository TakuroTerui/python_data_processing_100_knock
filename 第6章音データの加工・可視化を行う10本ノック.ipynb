# %%
cd /content/drive/MyDrive/100knock-process-visualization/chapter-6
# Out:
# /content/drive/MyDrive/100knock-process-visualization/chapter-6

# %% [markdown]
# ### ノック71：音データを再生してみよう

# %%
import IPython.display as disp
disp.Audio('data/音声.mp3')
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
disp.Audio('data/携帯電話着信音.mp3')
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ### ノック72：音データを読み込んでみよう

# %%
import librosa
audio1, sr1 = librosa.load('data/音声.mp3', sr=None)
print(audio1)
print(sr1)
# Out:
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# [ 0.          0.          0.         ... -0.00419617 -0.00418091
#  -0.00402832]
# 44100

# %%
print(audio1.shape)
print(audio1.max())
print(audio1.min())
# Out:
# (46080,)
# 0.71469116
# -0.55914307

# %%
audio2, sr2 = librosa.load('data/携帯電話着信音.mp3', sr=None)
print(audio2)
print(sr2)
print(audio2.shape)
# Out:
# [ 0.          0.          0.         ... -0.00509644 -0.0040741
#  -0.0032196 ]
# 44100
# (101376,)
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")

# %% [markdown]
# ### ノック73：音データの一部を取得してみよう

# %%
audio2, sr2 = librosa.load('data/携帯電話着信音.mp3', sr=None, offset=0, duration=1)
print(audio2)
print(sr2)
print(audio2.shape)
# Out:
# [0.0000000e+00 0.0000000e+00 0.0000000e+00 ... 9.1552734e-05 7.1716309e-04
#  1.8005371e-03]
# 44100
# (44100,)

# %%
disp.Audio(data=audio2, rate=sr2)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
audio1, sr1 = librosa.load('data/音声.mp3', sr=None, offset=0, duration=1)
disp.Audio(data=audio1, rate=sr1)
print(audio1.shape)
# Out:
# (44100,)
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")

# %% [markdown]
# ### ノック74：音データのサンプリングレートを変えてみよう

# %%
audio1_sr22, sr1_22 = librosa.load('data/音声.mp3', sr=22050, offset=0, duration=1)
print(audio1_sr22)
print(sr1_22)
print(audio1_sr22.shape)
# Out:
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# [0.         0.         0.         ... 0.00223347 0.00200565 0.00242361]
# 22050
# (22050,)

# %%
audio1_sr8 = librosa.resample(audio1, sr1, 8000)
print(audio1_sr8)
print(audio1_sr8.shape)
# Out:
# [0.         0.         0.         ... 0.00215728 0.0020847  0.00229463]
# (8000,)

# %%
librosa.get_samplerate('data/音声.mp3')
# Out:
# 44100

# %% [markdown]
# ### ノック75：音データを可視化してみよう

# %%
import librosa.display as libdisp
libdisp.waveplot(audio1, sr=sr1)

# %%
libdisp.waveplot(audio1_sr22, sr=sr1_22)

# %%
libdisp.waveplot(audio1_sr8, sr=8000)

# %%
libdisp.waveplot(audio2, sr=sr2)
